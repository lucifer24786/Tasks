# %% [markdown]
# <a href="https://colab.research.google.com/github/lucifer24786/Tasks/blob/main/LGM_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LetsGrowMore Task #Feb2022
#
# Task 1 : Iris flowers classification ML Project
#
# Author : Amaan Kadri
#
# Level : Beginner
#
# Language : Python
#
# Software : Google Colaboratory

# %% [markdown]
# ##Importing library and data

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets #Visualization
import seaborn as sns #Visualization
print("Library imported successfully..")
# Out:
# Library imported successfully..

# %%
from google.colab import drive #Mounting the notebook on Google Drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Load the iris dataset
iris_data_path = ("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")
iris_df = pd.read_csv(iris_data_path)
print("Dataset loaded successfully...")
# Out:
# Dataset loaded successfully...

# %% [markdown]
# ##Exploring Data

# %%
# Checking number of rows and columns in the data set
print('\nNumber of rows and columns in the data set: ',iris_df.shape)
# Out:
# Number of rows and columns in the data set:  (150, 5)

# %%
#Visualize Data
iris_df.head() # See the first 5 rows
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %%
iris_df['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %% [markdown]
# ##Visualising Data

# %% [markdown]
# ###Pair Plot

# %%
sns.pairplot(iris_df)
plt.show()

# %%
sns.pairplot(iris_df, hue='variety')
plt.show()

# %%
#To show the relationship between sepal length and sepal width and also the difference between petal lenght and petal width.
sns.countplot(x='variety', data = iris_df)
plt.show()

# %% [markdown]
# ###Heatmap

# %%
#Visualizing the Heatmap
plt.figure(figsize=(15,7))
sns.heatmap(iris_df.corr(), annot=True, cmap='cubehelix_r')
plt.show()

# %% [markdown]
# ##Model Building

# %% [markdown]
# ###Splitting Data in X & y

# %%
X = iris_df.drop(['variety'], axis=1)
y = iris_df['variety']
# print(X.head())
print(X.shape)
# print(y.head())
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %% [markdown]
# ###Split the dataset into a training set and a testing set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (112, 4)
# (112,)
# (38, 4)
# (38,)

# %% [markdown]
# ##Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
print("Training Completed...")
# Out:
# Training Completed...

# %% [markdown]
# ###Making Prediction

# %%
y_pred = logreg.predict(X_test)
print(y_pred)
# Out:
# ['Versicolor' 'Virginica' 'Virginica' 'Setosa' 'Virginica' 'Versicolor'
#  'Setosa' 'Virginica' 'Setosa' 'Versicolor' 'Versicolor' 'Virginica'
#  'Virginica' 'Virginica' 'Setosa' 'Setosa' 'Virginica' 'Virginica'
#  'Setosa' 'Setosa' 'Versicolor' 'Virginica' 'Setosa' 'Versicolor'
#  'Versicolor' 'Virginica' 'Versicolor' 'Versicolor' 'Versicolor'
#  'Virginica' 'Setosa' 'Versicolor' 'Versicolor' 'Setosa' 'Versicolor'
#  'Setosa' 'Setosa' 'Virginica']

# %% [markdown]
# ###Checking Accuracy

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9736842105263158

# %% [markdown]
# ##KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
print("Training Completed...")
# Out:
# Training Completed...

# %% [markdown]
# ###Making Prediction

# %%
y_pred_knn = knn.predict(X_test)
print(y_pred_knn)
# Out:
# ['Versicolor' 'Virginica' 'Virginica' 'Setosa' 'Virginica' 'Versicolor'
#  'Setosa' 'Virginica' 'Setosa' 'Versicolor' 'Versicolor' 'Virginica'
#  'Virginica' 'Virginica' 'Setosa' 'Setosa' 'Virginica' 'Virginica'
#  'Setosa' 'Setosa' 'Versicolor' 'Virginica' 'Setosa' 'Virginica'
#  'Versicolor' 'Virginica' 'Versicolor' 'Versicolor' 'Versicolor'
#  'Virginica' 'Setosa' 'Versicolor' 'Versicolor' 'Setosa' 'Versicolor'
#  'Setosa' 'Setosa' 'Virginica']

# %% [markdown]
# ###Checking Accuracy

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred_knn))
# Out:
# 0.9473684210526315
